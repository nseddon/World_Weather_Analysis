# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 629

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_current_description = city_weather["weather"]
        city_current_description = city_current_description[0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | wau
# Processing Record 5 of Set 1 | ponta do sol
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | lavrentiya
# Processing Record 8 of Set 1 | bengkulu
# Processing Record 9 of Set 1 | babanusah
# City not found. Skipping...
# Processing Record 10 of Set 1 | new norfolk
# Processing Record 11 of Set 1 | dikson
# Processing Record 12 of Set 1 | naze
# Processing Record 13 of Set 1 | big spring
# Processing Record 14 of Set 1 | prince rupert
# Processing Record 15 of Set 1 | russell
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | te anau
# Processing Record 18 of Set 1 | victoria
# Processing Record 19 of Set 1 | thompson
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | waipawa
# Processing Record 23 of Set 1 | bambous virieux
# Processing Record 24 of Set 1 | marystown
# Processing Record 25 of Set 1 | khatanga
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | saint-philippe
# Processing Record 30 of Set 1 | klaksvik
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | puerto escondido
# Processing Record 33 of Set 1 | evensk
# Processing Record 34 of Set 1 | smithers
# Processing Record 35 of Set 1 | verkhnyaya inta
# Processing Record 36 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | arraial do cabo
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | mezen
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | komsomolskiy
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | porbandar
# Processing Record 45 of Set 1 | arlit
# Processing Record 46 of Set 1 | barrow
# Processing Record 47 of Set 1 | luderitz
# Processing Record 48 of Set 1 | iqaluit
# Processing Record 49 of Set 1 | tiksi
# Processing Record 50 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 2 | san cristobal
# Processing Record 2 of Set 2 | nanortalik
# Processing Record 3 of Set 2 | sao filipe
# Processing Record 4 of Set 2 | meulaboh
# Processing Record 5 of Set 2 | nikolskoye
# Processing Record 6 of Set 2 | sambava
# Processing Record 7 of Set 2 | sitka
# Processing Record 8 of Set 2 | talnakh
# Processing Record 9 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 2 | ust-kut
# Processing Record 11 of Set 2 | shelburne
# Processing Record 12 of Set 2 | cabo san lucas
# Processing Record 13 of Set 2 | mildura
# Processing Record 14 of Set 2 | cedar city
# Processing Record 15 of Set 2 | cherskiy
# Processing Record 16 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 17 of Set 2 | arica
# Processing Record 18 of Set 2 | geraldton
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | matagami
# Processing Record 21 of Set 2 | luwuk
# Processing Record 22 of Set 2 | basco
# Processing Record 23 of Set 2 | marsa matruh
# Processing Record 24 of Set 2 | mandalgovi
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | ballina
# Processing Record 27 of Set 2 | torbay
# Processing Record 28 of Set 2 | doka
# Processing Record 29 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 30 of Set 2 | okhotsk
# Processing Record 31 of Set 2 | grand gaube
# Processing Record 32 of Set 2 | chokurdakh
# Processing Record 33 of Set 2 | salihorsk
# Processing Record 34 of Set 2 | tasiilaq
# Processing Record 35 of Set 2 | atuona
# Processing Record 36 of Set 2 | east london
# Processing Record 37 of Set 2 | norman wells
# Processing Record 38 of Set 2 | vaini
# Processing Record 39 of Set 2 | yellowknife
# Processing Record 40 of Set 2 | rzhev
# Processing Record 41 of Set 2 | novopavlovka
# Processing Record 42 of Set 2 | carnarvon
# Processing Record 43 of Set 2 | porto novo
# Processing Record 44 of Set 2 | fernandez
# Processing Record 45 of Set 2 | cockburn town
# Processing Record 46 of Set 2 | cape town
# Processing Record 47 of Set 2 | chumikan
# Processing Record 48 of Set 2 | taoudenni
# Processing Record 49 of Set 2 | ribeira grande
# Processing Record 50 of Set 2 | aracati
# Processing Record 1 of Set 3 | kapaa
# Processing Record 2 of Set 3 | tazovskiy
# Processing Record 3 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 3 | zhuozhou
# City not found. Skipping...
# Processing Record 6 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 3 | kavaratti
# Processing Record 8 of Set 3 | bredasdorp
# Processing Record 9 of Set 3 | baculin
# Processing Record 10 of Set 3 | hovd
# Processing Record 11 of Set 3 | jonava
# Processing Record 12 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 3 | monterey
# Processing Record 14 of Set 3 | saskylakh
# Processing Record 15 of Set 3 | traverse city
# Processing Record 16 of Set 3 | novobiryusinskiy
# Processing Record 17 of Set 3 | boa vista
# Processing Record 18 of Set 3 | constitucion
# Processing Record 19 of Set 3 | padang
# Processing Record 20 of Set 3 | kadoshkino
# Processing Record 21 of Set 3 | tezu
# Processing Record 22 of Set 3 | san rafael
# Processing Record 23 of Set 3 | folkestone
# Processing Record 24 of Set 3 | assiniboia
# Processing Record 25 of Set 3 | kamaishi
# Processing Record 26 of Set 3 | alice springs
# Processing Record 27 of Set 3 | narsaq
# Processing Record 28 of Set 3 | pevek
# Processing Record 29 of Set 3 | souillac
# Processing Record 30 of Set 3 | providencia
# Processing Record 31 of Set 3 | newport
# Processing Record 32 of Set 3 | jumla
# Processing Record 33 of Set 3 | mackenzie
# Processing Record 34 of Set 3 | mareeba
# Processing Record 35 of Set 3 | agirish
# Processing Record 36 of Set 3 | buala
# Processing Record 37 of Set 3 | lebu
# Processing Record 38 of Set 3 | castro
# Processing Record 39 of Set 3 | plouzane
# Processing Record 40 of Set 3 | noyabrsk
# Processing Record 41 of Set 3 | malanville
# Processing Record 42 of Set 3 | nyurba
# Processing Record 43 of Set 3 | jizan
# Processing Record 44 of Set 3 | ostrovnoy
# Processing Record 45 of Set 3 | manono
# Processing Record 46 of Set 3 | goderich
# Processing Record 47 of Set 3 | malabo
# Processing Record 48 of Set 3 | tongchuan
# Processing Record 49 of Set 3 | lompoc
# Processing Record 50 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 1 of Set 4 | jining
# Processing Record 2 of Set 4 | berezovyy
# Processing Record 3 of Set 4 | salalah
# Processing Record 4 of Set 4 | novyy urgal
# Processing Record 5 of Set 4 | fortuna
# Processing Record 6 of Set 4 | san ramon
# Processing Record 7 of Set 4 | ilulissat
# Processing Record 8 of Set 4 | gat
# Processing Record 9 of Set 4 | matir
# City not found. Skipping...
# Processing Record 10 of Set 4 | fort-shevchenko
# Processing Record 11 of Set 4 | bushehr
# Processing Record 12 of Set 4 | port elizabeth
# Processing Record 13 of Set 4 | klyuchi
# Processing Record 14 of Set 4 | nouadhibou
# Processing Record 15 of Set 4 | aklavik
# Processing Record 16 of Set 4 | kaspiyskiy
# Processing Record 17 of Set 4 | bobo dioulasso
# Processing Record 18 of Set 4 | mahebourg
# Processing Record 19 of Set 4 | sabha
# Processing Record 20 of Set 4 | port alfred
# Processing Record 21 of Set 4 | tiznit
# Processing Record 22 of Set 4 | upernavik
# Processing Record 23 of Set 4 | kaoma
# Processing Record 24 of Set 4 | haines junction
# Processing Record 25 of Set 4 | fort morgan
# Processing Record 26 of Set 4 | san patricio
# Processing Record 27 of Set 4 | dubti
# Processing Record 28 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 4 | bathsheba
# Processing Record 30 of Set 4 | anadyr
# Processing Record 31 of Set 4 | gushikawa
# Processing Record 32 of Set 4 | pimentel
# Processing Record 33 of Set 4 | wadi maliz
# Processing Record 34 of Set 4 | asyut
# Processing Record 35 of Set 4 | agaro
# Processing Record 36 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 37 of Set 4 | fort dodge
# Processing Record 38 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 4 | razole
# Processing Record 40 of Set 4 | bastia
# Processing Record 41 of Set 4 | hervey bay
# Processing Record 42 of Set 4 | misratah
# Processing Record 43 of Set 4 | vao
# Processing Record 44 of Set 4 | touros
# Processing Record 45 of Set 4 | mandurah
# Processing Record 46 of Set 4 | bonthe
# Processing Record 47 of Set 4 | dukat
# Processing Record 48 of Set 4 | centralia
# Processing Record 49 of Set 4 | carballo
# Processing Record 50 of Set 4 | balkhash
# Processing Record 1 of Set 5 | mabaruma
# Processing Record 2 of Set 5 | mount gambier
# Processing Record 3 of Set 5 | rapid valley
# Processing Record 4 of Set 5 | karamea
# City not found. Skipping...
# Processing Record 5 of Set 5 | chapais
# Processing Record 6 of Set 5 | kununurra
# Processing Record 7 of Set 5 | beian
# Processing Record 8 of Set 5 | shitanjing
# Processing Record 9 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 5 | airai
# Processing Record 11 of Set 5 | nizhniy baskunchak
# Processing Record 12 of Set 5 | rassvet
# Processing Record 13 of Set 5 | miranorte
# City not found. Skipping...
# Processing Record 14 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 5 | yar-sale
# Processing Record 16 of Set 5 | merauke
# Processing Record 17 of Set 5 | puerto ayora
# Processing Record 18 of Set 5 | mecca
# Processing Record 19 of Set 5 | ouadda
# Processing Record 20 of Set 5 | vangaindrano
# Processing Record 21 of Set 5 | sao joao da barra
# Processing Record 22 of Set 5 | hithadhoo
# Processing Record 23 of Set 5 | kodiak
# Processing Record 24 of Set 5 | pangnirtung
# Processing Record 25 of Set 5 | aksu
# Processing Record 26 of Set 5 | bure
# Processing Record 27 of Set 5 | sao gabriel da cachoeira
# Processing Record 28 of Set 5 | haimen
# Processing Record 29 of Set 5 | zhongshu
# Processing Record 30 of Set 5 | georgetown
# Processing Record 31 of Set 5 | pacific grove
# Processing Record 32 of Set 5 | dinsor
# City not found. Skipping...
# Processing Record 33 of Set 5 | opuwo
# Processing Record 34 of Set 5 | kibaya
# Processing Record 35 of Set 5 | lingyuan
# Processing Record 36 of Set 5 | sandwick
# Processing Record 37 of Set 5 | longyearbyen
# Processing Record 38 of Set 5 | glace bay
# Processing Record 39 of Set 5 | victoria point
# Processing Record 40 of Set 5 | veranopolis
# Processing Record 41 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 42 of Set 5 | le vauclin
# Processing Record 43 of Set 5 | madimba
# Processing Record 44 of Set 5 | karakendzha
# City not found. Skipping...
# Processing Record 45 of Set 5 | yanji
# Processing Record 46 of Set 5 | dingle
# Processing Record 47 of Set 5 | atikokan
# Processing Record 48 of Set 5 | tuktoyaktuk
# Processing Record 49 of Set 5 | sangin
# Processing Record 50 of Set 5 | kidal
# Processing Record 1 of Set 6 | rudnaya pristan
# Processing Record 2 of Set 6 | coquimbo
# Processing Record 3 of Set 6 | hohhot
# Processing Record 4 of Set 6 | saint george
# Processing Record 5 of Set 6 | hambantota
# Processing Record 6 of Set 6 | hirara
# Processing Record 7 of Set 6 | yangjiang
# Processing Record 8 of Set 6 | asau
# Processing Record 9 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 6 | lucenec
# Processing Record 11 of Set 6 | makaha
# Processing Record 12 of Set 6 | sioux lookout
# Processing Record 13 of Set 6 | samandag
# Processing Record 14 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 6 | khilok
# Processing Record 16 of Set 6 | rawson
# Processing Record 17 of Set 6 | leh
# Processing Record 18 of Set 6 | guanambi
# Processing Record 19 of Set 6 | kasongo-lunda
# Processing Record 20 of Set 6 | morristown
# Processing Record 21 of Set 6 | palmer
# Processing Record 22 of Set 6 | necochea
# Processing Record 23 of Set 6 | north bend
# Processing Record 24 of Set 6 | kavieng
# Processing Record 25 of Set 6 | virginia beach
# Processing Record 26 of Set 6 | stabat
# Processing Record 27 of Set 6 | chake chake
# Processing Record 28 of Set 6 | hasaki
# Processing Record 29 of Set 6 | biak
# Processing Record 30 of Set 6 | launceston
# Processing Record 31 of Set 6 | saint-francois
# Processing Record 32 of Set 6 | amahai
# Processing Record 33 of Set 6 | effium
# Processing Record 34 of Set 6 | faanui
# Processing Record 35 of Set 6 | quatre cocos
# Processing Record 36 of Set 6 | olga
# Processing Record 37 of Set 6 | bairiki
# Processing Record 38 of Set 6 | talakan
# Processing Record 39 of Set 6 | iquique
# Processing Record 40 of Set 6 | phrai bung
# City not found. Skipping...
# Processing Record 41 of Set 6 | broken hill
# Processing Record 42 of Set 6 | ndende
# Processing Record 43 of Set 6 | nampula
# Processing Record 44 of Set 6 | sapulpa
# Processing Record 45 of Set 6 | serrana
# Processing Record 46 of Set 6 | sijunjung
# Processing Record 47 of Set 6 | bubaque
# Processing Record 48 of Set 6 | taicheng
# Processing Record 49 of Set 6 | mancio lima
# Processing Record 50 of Set 6 | bonavista
# Processing Record 1 of Set 7 | vitoria da conquista
# Processing Record 2 of Set 7 | camacha
# Processing Record 3 of Set 7 | chuy
# Processing Record 4 of Set 7 | sopelana
# Processing Record 5 of Set 7 | puri
# Processing Record 6 of Set 7 | tabas
# Processing Record 7 of Set 7 | palau
# Processing Record 8 of Set 7 | uyuni
# Processing Record 9 of Set 7 | mantua
# Processing Record 10 of Set 7 | la ronge
# Processing Record 11 of Set 7 | oranjemund
# Processing Record 12 of Set 7 | port-cartier
# Processing Record 13 of Set 7 | micheweni
# Processing Record 14 of Set 7 | totskoye
# Processing Record 15 of Set 7 | mudyuga
# City not found. Skipping...
# Processing Record 16 of Set 7 | kaitangata
# Processing Record 17 of Set 7 | bahia blanca
# Processing Record 18 of Set 7 | pemba
# Processing Record 19 of Set 7 | tumsar
# Processing Record 20 of Set 7 | abu kamal
# Processing Record 21 of Set 7 | gawler
# Processing Record 22 of Set 7 | blyth
# Processing Record 23 of Set 7 | nioro
# Processing Record 24 of Set 7 | andenes
# Processing Record 25 of Set 7 | kashi
# Processing Record 26 of Set 7 | novyy urengoy
# Processing Record 27 of Set 7 | morgan hill
# Processing Record 28 of Set 7 | sindand
# City not found. Skipping...
# Processing Record 29 of Set 7 | batemans bay
# Processing Record 30 of Set 7 | bababe
# City not found. Skipping...
# Processing Record 31 of Set 7 | katsuura
# Processing Record 32 of Set 7 | fukue
# Processing Record 33 of Set 7 | fare
# Processing Record 34 of Set 7 | namibe
# Processing Record 35 of Set 7 | tuatapere
# Processing Record 36 of Set 7 | awjilah
# Processing Record 37 of Set 7 | acarau
# Processing Record 38 of Set 7 | umri
# Processing Record 39 of Set 7 | sorong
# Processing Record 40 of Set 7 | jahazpur
# Processing Record 41 of Set 7 | hami
# Processing Record 42 of Set 7 | yerbogachen
# Processing Record 43 of Set 7 | paamiut
# Processing Record 44 of Set 7 | hobyo
# Processing Record 45 of Set 7 | kutum
# Processing Record 46 of Set 7 | whyalla
# Processing Record 47 of Set 7 | esperance
# Processing Record 48 of Set 7 | oistins
# Processing Record 49 of Set 7 | samana
# Processing Record 50 of Set 7 | ulagan
# Processing Record 1 of Set 8 | yuanping
# Processing Record 2 of Set 8 | miyako
# Processing Record 3 of Set 8 | lagoa
# Processing Record 4 of Set 8 | kapit
# Processing Record 5 of Set 8 | nemuro
# Processing Record 6 of Set 8 | clyde river
# Processing Record 7 of Set 8 | adrar
# Processing Record 8 of Set 8 | madang
# Processing Record 9 of Set 8 | mahibadhoo
# Processing Record 10 of Set 8 | llaillay
# Processing Record 11 of Set 8 | bethel
# Processing Record 12 of Set 8 | naruto
# Processing Record 13 of Set 8 | guerrero negro
# Processing Record 14 of Set 8 | cidreira
# Processing Record 15 of Set 8 | port blair
# Processing Record 16 of Set 8 | kerema
# Processing Record 17 of Set 8 | varberg
# Processing Record 18 of Set 8 | esmeraldas
# Processing Record 19 of Set 8 | cap malheureux
# Processing Record 20 of Set 8 | mbekenyera
# Processing Record 21 of Set 8 | beringovskiy
# Processing Record 22 of Set 8 | kloulklubed
# Processing Record 23 of Set 8 | damme
# Processing Record 24 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 25 of Set 8 | lubao
# Processing Record 26 of Set 8 | wegorzewo
# Processing Record 27 of Set 8 | severo-kurilsk
# Processing Record 28 of Set 8 | monrovia
# Processing Record 29 of Set 8 | fairbanks
# Processing Record 30 of Set 8 | hofn
# Processing Record 31 of Set 8 | dese
# Processing Record 32 of Set 8 | talaya
# Processing Record 33 of Set 8 | saint anthony
# Processing Record 34 of Set 8 | indramayu
# Processing Record 35 of Set 8 | atar
# Processing Record 36 of Set 8 | aybak
# City not found. Skipping...
# Processing Record 37 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 38 of Set 8 | abilene
# Processing Record 39 of Set 8 | san jose
# Processing Record 40 of Set 8 | ilhabela
# Processing Record 41 of Set 8 | san angelo
# Processing Record 42 of Set 8 | broome
# Processing Record 43 of Set 8 | naranjal
# Processing Record 44 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 45 of Set 8 | perry
# Processing Record 46 of Set 8 | nalut
# Processing Record 47 of Set 8 | ancud
# Processing Record 48 of Set 8 | guadalupe y calvo
# Processing Record 49 of Set 8 | neijiang
# Processing Record 50 of Set 8 | araouane
# Processing Record 1 of Set 9 | xai-xai
# Processing Record 2 of Set 9 | am timan
# Processing Record 3 of Set 9 | sinnamary
# Processing Record 4 of Set 9 | ponta delgada
# Processing Record 5 of Set 9 | caxito
# Processing Record 6 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 9 | moree
# Processing Record 8 of Set 9 | richards bay
# Processing Record 9 of Set 9 | otradnoye
# Processing Record 10 of Set 9 | gualaca
# Processing Record 11 of Set 9 | plettenberg bay
# Processing Record 12 of Set 9 | sept-iles
# Processing Record 13 of Set 9 | abu dhabi
# Processing Record 14 of Set 9 | nsanje
# Processing Record 15 of Set 9 | alofi
# Processing Record 16 of Set 9 | camacupa
# Processing Record 17 of Set 9 | tiarei
# Processing Record 18 of Set 9 | pisco
# Processing Record 19 of Set 9 | orcopampa
# Processing Record 20 of Set 9 | muisne
# Processing Record 21 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 9 | roald
# Processing Record 23 of Set 9 | dergachi
# Processing Record 24 of Set 9 | guacimo
# Processing Record 25 of Set 9 | ciras
# City not found. Skipping...
# Processing Record 26 of Set 9 | vila franca do campo
# Processing Record 27 of Set 9 | manzil tamim
# City not found. Skipping...
# Processing Record 28 of Set 9 | rio cuarto
# Processing Record 29 of Set 9 | bereda
# Processing Record 30 of Set 9 | tura
# Processing Record 31 of Set 9 | linqiong
# Processing Record 32 of Set 9 | kupang
# Processing Record 33 of Set 9 | vila
# Processing Record 34 of Set 9 | karratha
# Processing Record 35 of Set 9 | svetlaya
# Processing Record 36 of Set 9 | baruun-urt
# Processing Record 37 of Set 9 | rio grande
# Processing Record 38 of Set 9 | yarmouth
# Processing Record 39 of Set 9 | alta
# Processing Record 40 of Set 9 | nabire
# Processing Record 41 of Set 9 | malanje
# Processing Record 42 of Set 9 | letlhakeng
# Processing Record 43 of Set 9 | shingu
# Processing Record 44 of Set 9 | gizo
# Processing Record 45 of Set 9 | jinchang
# Processing Record 46 of Set 9 | provideniya
# Processing Record 47 of Set 9 | ciudad bolivar
# Processing Record 48 of Set 9 | isangel
# Processing Record 49 of Set 9 | shieli
# Processing Record 50 of Set 9 | san ramon de la nueva oran
# Processing Record 1 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 2 of Set 10 | harstad
# Processing Record 3 of Set 10 | saldanha
# Processing Record 4 of Set 10 | prodromos
# Processing Record 5 of Set 10 | palairos
# Processing Record 6 of Set 10 | bonga
# Processing Record 7 of Set 10 | ascension
# Processing Record 8 of Set 10 | ferkessedougou
# Processing Record 9 of Set 10 | novo oriente
# Processing Record 10 of Set 10 | manggar
# Processing Record 11 of Set 10 | cayenne
# Processing Record 12 of Set 10 | mezhdurechensk
# Processing Record 13 of Set 10 | port lincoln
# Processing Record 14 of Set 10 | rodbyhavn
# Processing Record 15 of Set 10 | yaqui
# Processing Record 16 of Set 10 | xining
# Processing Record 17 of Set 10 | lorengau
# Processing Record 18 of Set 10 | novokuznetsk
# Processing Record 19 of Set 10 | garissa
# Processing Record 20 of Set 10 | zhigalovo
# Processing Record 21 of Set 10 | ahipara
# Processing Record 22 of Set 10 | flinders
# Processing Record 23 of Set 10 | fontaine
# Processing Record 24 of Set 10 | yelkhovka
# Processing Record 25 of Set 10 | georgiyevka
# Processing Record 26 of Set 10 | akom
# Processing Record 27 of Set 10 | sakakah
# Processing Record 28 of Set 10 | eidfjord
# Processing Record 29 of Set 10 | parati
# Processing Record 30 of Set 10 | breza
# Processing Record 31 of Set 10 | port hedland
# Processing Record 32 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 33 of Set 10 | deputatskiy
# Processing Record 34 of Set 10 | kattivakkam
# Processing Record 35 of Set 10 | juneau
# Processing Record 36 of Set 10 | najran
# Processing Record 37 of Set 10 | bulawayo
# Processing Record 38 of Set 10 | margate
# Processing Record 39 of Set 10 | kota kinabalu
# Processing Record 40 of Set 10 | kodinar
# Processing Record 41 of Set 10 | vardo
# Processing Record 42 of Set 10 | erenhot
# Processing Record 43 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 44 of Set 10 | toamasina
# Processing Record 45 of Set 10 | clayton
# Processing Record 46 of Set 10 | byron bay
# Processing Record 47 of Set 10 | kirovskiy
# Processing Record 48 of Set 10 | dipkarpaz
# City not found. Skipping...
# Processing Record 49 of Set 10 | kokopo
# Processing Record 50 of Set 10 | saint-pierre
# Processing Record 1 of Set 11 | kuching
# Processing Record 2 of Set 11 | gazanjyk
# Processing Record 3 of Set 11 | minot
# Processing Record 4 of Set 11 | dunda
# Processing Record 5 of Set 11 | havelock
# Processing Record 6 of Set 11 | korla
# Processing Record 7 of Set 11 | nadym
# Processing Record 8 of Set 11 | koslan
# Processing Record 9 of Set 11 | omsukchan
# Processing Record 10 of Set 11 | khotkovo
# Processing Record 11 of Set 11 | san quintin
# Processing Record 12 of Set 11 | berlevag
# Processing Record 13 of Set 11 | miracema do tocantins
# Processing Record 14 of Set 11 | bocaranga
# City not found. Skipping...
# Processing Record 15 of Set 11 | kahului
# Processing Record 16 of Set 11 | makakilo city
# Processing Record 17 of Set 11 | curuguaty
# Processing Record 18 of Set 11 | garden city
# Processing Record 19 of Set 11 | balod
# Processing Record 20 of Set 11 | dzaoudzi
# Processing Record 21 of Set 11 | acari
# Processing Record 22 of Set 11 | natal
# Processing Record 23 of Set 11 | abonnema
# Processing Record 24 of Set 11 | tual
# Processing Record 25 of Set 11 | barranca
# Processing Record 26 of Set 11 | hamilton
# Processing Record 27 of Set 11 | rundu
# Processing Record 28 of Set 11 | brae
# Processing Record 29 of Set 11 | mehran
# Processing Record 30 of Set 11 | sierpc
# Processing Record 31 of Set 11 | haapiti
# Processing Record 32 of Set 11 | los llanos de aridane
# Processing Record 33 of Set 11 | bafoulabe
# Processing Record 34 of Set 11 | buraydah
# Processing Record 35 of Set 11 | khanpur
# Processing Record 36 of Set 11 | nome
# Processing Record 37 of Set 11 | yulara
# Processing Record 38 of Set 11 | vestmannaeyjar
# Processing Record 39 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 11 | sorland
# Processing Record 41 of Set 11 | amvrosiyivka
# Processing Record 42 of Set 11 | antofagasta
# Processing Record 43 of Set 11 | sergeyevka
# Processing Record 44 of Set 11 | belomorsk
# Processing Record 45 of Set 11 | codrington
# Processing Record 46 of Set 11 | ketchikan
# Processing Record 47 of Set 11 | osmena
# Processing Record 48 of Set 11 | daru
# Processing Record 49 of Set 11 | shkotovo-26
# City not found. Skipping...
# Processing Record 50 of Set 11 | naryan-mar
# Processing Record 1 of Set 12 | puerto ayacucho
# Processing Record 2 of Set 12 | benemerito de las americas
# Processing Record 3 of Set 12 | dunedin
# Processing Record 4 of Set 12 | mizpe ramon
# City not found. Skipping...
# Processing Record 5 of Set 12 | nortelandia
# Processing Record 6 of Set 12 | mogadishu
# Processing Record 7 of Set 12 | poronaysk
# Processing Record 8 of Set 12 | troyes
# Processing Record 9 of Set 12 | pilar do sul
# Processing Record 10 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 11 of Set 12 | ulladulla
# Processing Record 12 of Set 12 | paka
# Processing Record 13 of Set 12 | bac lieu
# Processing Record 14 of Set 12 | comodoro rivadavia
# Processing Record 15 of Set 12 | nantucket
# Processing Record 16 of Set 12 | sokolo
# Processing Record 17 of Set 12 | atka
# City not found. Skipping...
# Processing Record 18 of Set 12 | sungaipenuh
# Processing Record 19 of Set 12 | riyadh
# Processing Record 20 of Set 12 | mwinilunga
# Processing Record 21 of Set 12 | payo
# Processing Record 22 of Set 12 | somvarpet
# Processing Record 23 of Set 12 | verkhoyansk
# Processing Record 24 of Set 12 | sola
# Processing Record 25 of Set 12 | guane
# Processing Record 26 of Set 12 | quime
# Processing Record 27 of Set 12 | portland
# Processing Record 28 of Set 12 | viedma
# Processing Record 29 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 30 of Set 12 | presidencia roque saenz pena
# Processing Record 31 of Set 12 | pochutla
# Processing Record 32 of Set 12 | varhaug
# Processing Record 33 of Set 12 | ambon
# Processing Record 34 of Set 12 | cairns
# Processing Record 35 of Set 12 | koumac
# Processing Record 36 of Set 12 | puntarenas
# Processing Record 37 of Set 12 | coahuayana
# Processing Record 38 of Set 12 | malaya serdoba
# Processing Record 39 of Set 12 | flin flon
# Processing Record 40 of Set 12 | beoumi
# Processing Record 41 of Set 12 | kantang
# Processing Record 42 of Set 12 | kirakira
# Processing Record 43 of Set 12 | encheng
# Processing Record 44 of Set 12 | vestmanna
# Processing Record 45 of Set 12 | saint-joseph
# Processing Record 46 of Set 12 | belmonte
# Processing Record 47 of Set 12 | salo
# Processing Record 48 of Set 12 | yukamenskoye
# Processing Record 49 of Set 12 | kimbe
# Processing Record 50 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 1 of Set 13 | auki
# Processing Record 2 of Set 13 | uvinza
# Processing Record 3 of Set 13 | windhoek
# Processing Record 4 of Set 13 | kafanchan
# Processing Record 5 of Set 13 | athol
# Processing Record 6 of Set 13 | lexington
# Processing Record 7 of Set 13 | shirokiy
# Processing Record 8 of Set 13 | waddan
# Processing Record 9 of Set 13 | borovskoy
# Processing Record 10 of Set 13 | casper
# Processing Record 11 of Set 13 | naantali
# Processing Record 12 of Set 13 | katima mulilo
# Processing Record 13 of Set 13 | mutis
# Processing Record 14 of Set 13 | linares
# Processing Record 15 of Set 13 | gwanda
# Processing Record 16 of Set 13 | ginir
# Processing Record 17 of Set 13 | novyye burasy
# Processing Record 18 of Set 13 | kilosa
# Processing Record 19 of Set 13 | whitehorse
# Processing Record 20 of Set 13 | lata
# Processing Record 21 of Set 13 | raudeberg
# Processing Record 22 of Set 13 | tadine
# Processing Record 23 of Set 13 | bajil
# Processing Record 24 of Set 13 | divnomorskoye
# Processing Record 25 of Set 13 | waharoa
# Processing Record 26 of Set 13 | upata
# Processing Record 27 of Set 13 | victor harbor
# Processing Record 28 of Set 13 | usinsk
# Processing Record 29 of Set 13 | oktyabrskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Albany      US  42.6001  -73.9662     64.31        87         100
# 1    Butaritari      KI   3.0707  172.7902     81.86        77          17
# 2           Wau      SS   7.7029   27.9953     72.72        88          80
# 3  Ponta Do Sol      PT  32.6667  -17.1000     72.23        73          97
# 4     Jamestown      US  42.0970  -79.2353     68.72        82          90
# 5    Lavrentiya      RU  65.5833 -171.0000     34.52        82         100
# 6      Bengkulu      ID  -3.8004  102.2655     84.56        67          13
# 7   New Norfolk      AU -42.7826  147.0587     60.71        68          96
# 8        Dikson      RU  73.5069   80.5464     28.33        74         100
# 9          Naze      JP  28.3667  129.4833     83.32        83          37
#
#    Wind Speed Current Description
# 0        1.99     overcast clouds
# 1       12.66          light rain
# 2        3.31       broken clouds
# 3        3.56     overcast clouds
# 4        6.91     overcast clouds
# 5       18.92     overcast clouds
# 6        9.60          few clouds
# 7        1.01     overcast clouds
# 8       23.04          light snow
# 9       19.75    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
